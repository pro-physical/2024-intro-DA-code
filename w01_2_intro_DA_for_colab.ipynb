# %% [markdown]
# <a href="https://colab.research.google.com/github/pro-physical/2024-intro-DA-code/blob/main/w01_2_intro_DA_for_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 데이터분석입문

# %% [markdown]
# ## 01주 코딩

# %% [markdown]
# 코랩을 위한 주피터 노트북 기초

# %% [markdown]
# ```
# # 코드로 형식 지정됨
# ```

# %%
# %config InlineBackend.figure_formet
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-70639b6c12aa> in <cell line: 1>()
# ----> 1 get_ipython().run_line_magic('config', 'InlineBackend.figure_formet')
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2416                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2417             with self.builtin_trap:
# -> 2418                 result = fn(*args, **kwargs)
#    2419             return result
#    2420
#
# <decorator-gen-41> in config(self, s)
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ...

# %%
# !pip install koreanize-matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 45.1 MB/s eta 0:00:00
# ...

# %%
import koreanize_matplotlib

# %%
import matplotlib.pyplot as plt

plt.title("데이터 시각화의 한글 준비와 기본 직선 그래프")
plt.plot([10, 5, 25, 30])
plt.show()

# %%
import matplotlib.pyplot as plt

plt.title("데이터 시각화의 한글 준비와 기본 직선 그래프")
plt.plot([0, 1, 2, 3][10, 5, 25, 30])
plt.show()
# Out:
# <>:4: SyntaxWarning: list indices must be integers or slices, not tuple; perhaps you missed a comma?
# <>:4: SyntaxWarning: list indices must be integers or slices, not tuple; perhaps you missed a comma?
# <ipython-input-11-7dbb77da13d9>:4: SyntaxWarning: list indices must be integers or slices, not tuple; perhaps you missed a comma?
#   plt.plot([0, 1, 2, 3][10, 5, 25, 30])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-7dbb77da13d9> in <cell line: 4>()
#       2
#       3 plt.title("데이터 시각화의 한글 준비와 기본 직선 그래프")
# ----> 4 plt.plot([0, 1, 2, 3][10, 5, 25, 30])
#       5 plt.show()
#
# TypeError: list indices must be integers or slices, not tuple
